# %% [markdown]
# # Exploration Data Analysis

# %%
# Main Lib
import numpy as np
import pandas as pd

pd.set_option('display.width', 1000)
pd.set_option('display.max_columns', 1000)

import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../Dataset/Hotspot_Final.csv", parse_dates=['acq_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 276 entries, 0 to 275
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   acq_date  276 non-null    datetime64[ns]
#  1   sst_std   276 non-null    float64
#  2   sst_anom  276 non-null    float64
#  3   oni_std   276 non-null    float64
#  4   oni_anom  276 non-null    float64
#  5   soi_std   276 non-null    float64
#  6   soi_anom  276 non-null    float64
#  7   hotspot   276 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 17.4 KB

# %%
df
# Out:
#       acq_date  sst_std  sst_anom  oni_std  oni_anom  soi_std  soi_anom  hotspot
# 0   2001-01-31    25.81     -0.76    25.88     -0.68      1.0       1.6       27
# 1   2001-02-28    26.18     -0.56    26.26     -0.52      1.7       2.8       24
# 2   2001-03-31    26.86     -0.37    26.76     -0.44      0.9       1.5       29
# 3   2001-04-30    27.24     -0.56    27.25     -0.34      0.2       0.3       30
# 4   2001-05-31    27.42     -0.46    27.49     -0.25     -0.5      -0.8       31
# ..         ...      ...       ...      ...       ...      ...       ...      ...
# 271 2023-08-31    28.20      1.30    28.28      1.32     -0.8      -1.4       31
# 272 2023-09-30    28.29      1.53    28.32      1.56     -1.3      -2.1       30
# 273 2023-10-31    28.36      1.59    28.49      1.78     -0.5      -0.8       31
# 274 2023-11-30    28.72      1.90    28.60      1.92     -0.8      -1.3       30
# 275 2023-12-31    28.64      1.99    28.59      1.97     -0.2      -0.4       31
#
# [276 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(8, 4))

sns.lineplot(data=df, x="acq_date", y="soi_anom")

ax.set_title('Fire Forest on Indonesia from 2001 to 2023')
ax.set_xlabel('Date')
ax.set_ylabel('Frequency')
ax.legend(loc="best")
ax.grid(True)

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
